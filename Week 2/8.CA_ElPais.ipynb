# %%
import pyreadr
import prince
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from functions.ca_mca_plot import ca_plot

# %%
# Load your data 
df = pyreadr.read_r("data/ElPaisTable.RData")['F']
print("Original Data Preview:\n", df.head())

# %%
# Perform Correspondence Analysis
ca = prince.CA(n_components=df.shape[1]-1)
ca = ca.fit(df)

# %%
ca_plot(ca, df)

# %%
ca_plot(ca, df, plot="rows")

# %%
ca_plot(ca, df, plot="cols")
