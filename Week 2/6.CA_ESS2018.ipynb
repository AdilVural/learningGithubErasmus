# %%
import pyreadr
import prince
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read data from R:
df = pyreadr.read_r("data/vote&happy.RData")['T1']
print("Original Data Preview:\n", df.head())

# %%
# Perform Correspondence Analysis
ca = prince.CA(n_components = df.shape[1]-1) #number of columns -1 components
ca = ca.fit(df)

# %%
from functions.ca_mca_plot import ca_plot

ca_plot(ca, df, title = "Voting & Happiness")
